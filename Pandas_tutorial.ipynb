# %%
import pandas as pd
df = pd.read_csv('E:\Downloads\weather.csv')
pd
# Out:
# <module 'pandas' from 'C:\\Users\\Hp\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
import pandas as pd
df = pd.read_csv('E:\Downloads\weather.csv')
print(df)
# Out:
#       Unnamed: 0      Time  Temperature  Dew Point  Humidity  Wind Speed  \
# 0              0  12:00 AM           61         59        94          15
# 1              1  12:23 AM           61         59        94          20
# 2              2  12:30 AM           63         59        88          24
# 3              3  12:34 AM           63         59        88          23
# 4              4  12:47 AM           63         59        88          22
# ...          ...       ...          ...        ...       ...         ...
# 1992          51   9:30 PM           64         63        94           6
# 1993          52  10:00 PM           64         63        94           6
# 1994          53  10:30 PM           64         63        94           5
# 1995          54  11:00 PM           64         63        94           6
# 1996          55  11:30 PM           64         61        88           5
#
#       Wind Gust  Pressure  Precipitation Wind                  Condition  \
# ...

# %%
import pandas as pd
df = pd.read_csv('E:\Downloads\weather.csv')
df
# Out:
#       Unnamed: 0      Time  Temperature  Dew Point  Humidity  Wind Speed  \
# 0              0  12:00 AM           61         59        94          15
# 1              1  12:23 AM           61         59        94          20
# 2              2  12:30 AM           63         59        88          24
# 3              3  12:34 AM           63         59        88          23
# 4              4  12:47 AM           63         59        88          22
# ...          ...       ...          ...        ...       ...         ...
# 1992          51   9:30 PM           64         63        94           6
# 1993          52  10:00 PM           64         63        94           6
# 1994          53  10:30 PM           64         63        94           5
# 1995          54  11:00 PM           64         63        94           6
# 1996          55  11:30 PM           64         61        88           5
#
#       Wind Gust  Pressure  Precipitation Wind                  Condition  \
# ...

# %%
df.to_csv('new.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11136\3765791542.py in <module>
# ----> 1 df.to_csv('new.csv')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv('E:\Downloads\weather.csv')
df
# Out:
#       Unnamed: 0      Time  Temperature  Dew Point  Humidity  Wind Speed  \
# 0              0  12:00 AM           61         59        94          15
# 1              1  12:23 AM           61         59        94          20
# 2              2  12:30 AM           63         59        88          24
# 3              3  12:34 AM           63         59        88          23
# 4              4  12:47 AM           63         59        88          22
# ...          ...       ...          ...        ...       ...         ...
# 1992          51   9:30 PM           64         63        94           6
# 1993          52  10:00 PM           64         63        94           6
# 1994          53  10:30 PM           64         63        94           5
# 1995          54  11:00 PM           64         63        94           6
# 1996          55  11:30 PM           64         61        88           5
#
#       Wind Gust  Pressure  Precipitation Wind                  Condition  \
# ...

# %%
df.to_csv('new.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11136\779434368.py in <module>
# ----> 1 df.to_csv('new.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
# ...

# %%
df.to_csv('new1.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11136\779434368.py in <module>
# ----> 1 df.to_csv('new.csv')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
# ...

# %%
df.to_csv('new1.csv')

# %%
df.to_csv('new.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11136\3574342055.py in <module>
# ----> 1 df.to_csv('new.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
df.to_csv('new.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv("E:\Downloads\weather (1).csv", parse_dates=["Day"])
type(df.Day[2])
# Out:
# str

# %%
import pandas as pd
df = pd.read_csv("E:\Downloads\weather (1).csv", parse_dates=["Day"])
df.set_index('Day',inplace=True)
df
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                  77         9.69           221.99
# 2       1         28.79                  79        13.04           219.40
# 2       2         28.59                  79         7.99           215.84
# 2       3         28.47                  79         5.48           203.20
# 2       4         28.40                  78         5.24           195.95
# ..    ...           ...                 ...          ...              ...
# 9      19         28.66                  77        23.51           229.97
# 9      20         28.53                  78        22.73           229.50
# 9      21         28.44                  78        22.41           226.30
# 9      22         28.44                  79        22.67           223.07
# 9      23         28.42                  79        22.73           220.50
#
# [192 rows x 5 columns]

# %%
new_df = df.fillna(0)
new_df
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                  77         9.69           221.99
# 2       1         28.79                  79        13.04           219.40
# 2       2         28.59                  79         7.99           215.84
# 2       3         28.47                  79         5.48           203.20
# 2       4         28.40                  78         5.24           195.95
# ..    ...           ...                 ...          ...              ...
# 9      19         28.66                  77        23.51           229.97
# 9      20         28.53                  78        22.73           229.50
# 9      21         28.44                  78        22.41           226.30
# 9      22         28.44                  79        22.67           223.07
# 9      23         28.42                  79        22.73           220.50
#
# [192 rows x 5 columns]

# %%
import pandas as pd
df1 = pd.read_csv('C:\\Users\\Hp\\OneDrive\\Documents\\new111.csv')
df1
# Out:
#    Day  Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# 0    2     0         28.94                 NaN         9.69           221.99
# 1    2     1         28.79                79.0        13.04           219.40
# 2    2     2           NaN                79.0         7.99           215.84
# 3    2     3         28.47                79.0         5.48              NaN
# 4    2     4         28.40                 NaN         5.24           195.95
# 5    2     5         28.45                78.0         3.88           201.80
# 6    2     6         28.50                78.0         2.62           254.05
# 7    2     7         28.69                78.0          NaN           296.57
# 8    2     8         29.18                76.0         2.97           284.04

# %%
df1.set_index('Day', inplace = True)
df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2           NaN                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48              NaN
# 2       4         28.40                 NaN         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0          NaN           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df1 = df1.fillna(0)
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 0.0         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2          0.00                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48             0.00
# 2       4         28.40                 0.0         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0         0.00           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df2 = df1.fillna({
    'Temperature':0,
    'Relative Humidity':0,
    'Wind Speed':'no speed',
    'Wind Direction':'no direction'
    })
new_df2
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2           NaN                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48              NaN
# 2       4         28.40                 NaN         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0          NaN           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df1 = df1.fillna(method="ffill")
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2         28.79                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48           215.84
# 2       4         28.40                79.0         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0         2.62           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df1 = df1.fillna(method="bfill")
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                79.0         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2         28.47                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48           195.95
# 2       4         28.40                78.0         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0         2.97           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df1 = df1.fillna(method="bfill", axis = "columns")
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2     0.0         28.94                9.69         9.69           221.99
# 2     1.0         28.79               79.00        13.04           219.40
# 2     2.0         79.00               79.00         7.99           215.84
# 2     3.0         28.47               79.00         5.48              NaN
# 2     4.0         28.40                5.24         5.24           195.95
# 2     5.0         28.45               78.00         3.88           201.80
# 2     6.0         28.50               78.00         2.62           254.05
# 2     7.0         28.69               78.00       296.57           296.57
# 2     8.0         29.18               76.00         2.97           284.04

# %%
new_df1 = df1.interpolate()
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN        9.690          221.990
# 2       1         28.79                79.0       13.040          219.400
# 2       2         28.63                79.0        7.990          215.840
# 2       3         28.47                79.0        5.480          205.895
# 2       4         28.40                78.5        5.240          195.950
# 2       5         28.45                78.0        3.880          201.800
# 2       6         28.50                78.0        2.620          254.050
# 2       7         28.69                78.0        2.795          296.570
# 2       8         29.18                76.0        2.970          284.040

# %%
new_df1 = df1.interpolate()
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN        9.690          221.990
# 2       1         28.79                79.0       13.040          219.400
# 2       2         28.63                79.0        7.990          215.840
# 2       3         28.47                79.0        5.480          205.895
# 2       4         28.40                78.5        5.240          195.950
# 2       5         28.45                78.0        3.880          201.800
# 2       6         28.50                78.0        2.620          254.050
# 2       7         28.69                78.0        2.795          296.570
# 2       8         29.18                76.0        2.970          284.040

# %%
new_df1 = df1.dropna()
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       1         28.79                79.0        13.04           219.40
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       8         29.18                76.0         2.97           284.04

# %%
new_df1 = df1.dropna(how = "all")
new_df1
# Out:
#      Hour  Temperature   Relative Humidity   Wind Speed   Wind Direction
# Day
# 2       0         28.94                 NaN         9.69           221.99
# 2       1         28.79                79.0        13.04           219.40
# 2       2           NaN                79.0         7.99           215.84
# 2       3         28.47                79.0         5.48              NaN
# 2       4         28.40                 NaN         5.24           195.95
# 2       5         28.45                78.0         3.88           201.80
# 2       6         28.50                78.0         2.62           254.05
# 2       7         28.69                78.0          NaN           296.57
# 2       8         29.18                76.0         2.97           284.04

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\Hp\\OneDrive\\Documents\\data1.csv")
df
# Out:
#            day  temperature  windspeed  event  Unnamed: 4
# 0   01-01-2017         32.0        6.0   Rain         NaN
# 1   01-02-2017     -99999.0        7.0  Sunny         NaN
# 2   01-03-2017         28.0   -99999.0   Snow         NaN
# 3   01-04-2017     -99999.0        7.0      0         NaN
# 4   01-05-2017         32.0   -99999.0   Rain         NaN
# 5   01-06-2017         31.0        2.0  Sunny         NaN
# 6   01-06-2017         34.0        5.0      0         NaN
# 7          NaN          NaN        NaN    NaN         NaN
# 8          NaN          NaN        NaN    NaN         NaN
# 9          NaN          NaN        NaN    NaN         NaN
# 10         NaN          NaN        NaN    NaN         NaN
# 11         NaN          NaN        NaN    NaN         NaN
# 12         NaN          NaN        NaN    NaN         NaN
# 13         NaN          NaN        NaN    NaN         NaN
# 14         NaN          NaN        NaN    NaN         NaN
# ...

# %%
new_df = df.replace(-99999, np.NaN)
new_df
# Out:
#            day  temperature  windspeed  event  Unnamed: 4
# 0   01-01-2017         32.0        6.0   Rain         NaN
# 1   01-02-2017          NaN        7.0  Sunny         NaN
# 2   01-03-2017         28.0        NaN   Snow         NaN
# 3   01-04-2017          NaN        7.0      0         NaN
# 4   01-05-2017         32.0        NaN   Rain         NaN
# 5   01-06-2017         31.0        2.0  Sunny         NaN
# 6   01-06-2017         34.0        5.0      0         NaN
# 7          NaN          NaN        NaN    NaN         NaN
# 8          NaN          NaN        NaN    NaN         NaN
# 9          NaN          NaN        NaN    NaN         NaN
# 10         NaN          NaN        NaN    NaN         NaN
# 11         NaN          NaN        NaN    NaN         NaN
# 12         NaN          NaN        NaN    NaN         NaN
# 13         NaN          NaN        NaN    NaN         NaN
# 14         NaN          NaN        NaN    NaN         NaN
# ...

# %%
new_df = df.dropna(how = "all")
new_df
# Out:
#           day  temperature  windspeed  event  Unnamed: 4
# 0  01-01-2017         32.0        6.0   Rain         NaN
# 1  01-02-2017     -99999.0        7.0  Sunny         NaN
# 2  01-03-2017         28.0   -99999.0   Snow         NaN
# 3  01-04-2017     -99999.0        7.0      0         NaN
# 4  01-05-2017         32.0   -99999.0   Rain         NaN
# 5  01-06-2017         31.0        2.0  Sunny         NaN
# 6  01-06-2017         34.0        5.0      0         NaN

# %%
new_df = df.replace({
        'temperature':-99999,
        'windspeed':-99999,
        'event':'0'
},np.NaN)
new_df
# Out:
#            day  temperature  windspeed  event  Unnamed: 4
# 0   01-01-2017         32.0        6.0   Rain         NaN
# 1   01-02-2017          NaN        7.0  Sunny         NaN
# 2   01-03-2017         28.0        NaN   Snow         NaN
# 3   01-04-2017          NaN        7.0    NaN         NaN
# 4   01-05-2017         32.0        NaN   Rain         NaN
# 5   01-06-2017         31.0        2.0  Sunny         NaN
# 6   01-06-2017         34.0        5.0    NaN         NaN
# 7          NaN          NaN        NaN    NaN         NaN
# 8          NaN          NaN        NaN    NaN         NaN
# 9          NaN          NaN        NaN    NaN         NaN
# 10         NaN          NaN        NaN    NaN         NaN
# 11         NaN          NaN        NaN    NaN         NaN
# 12         NaN          NaN        NaN    NaN         NaN
# 13         NaN          NaN        NaN    NaN         NaN
# 14         NaN          NaN        NaN    NaN         NaN
# ...

# %%
df
# Out:
#            day  temperature  windspeed  event  Unnamed: 4
# 0   01-01-2017         32.0        6.0   Rain         NaN
# 1   01-02-2017     -99999.0        7.0  Sunny         NaN
# 2   01-03-2017         28.0   -99999.0   Snow         NaN
# 3   01-04-2017     -99999.0        7.0      0         NaN
# 4   01-05-2017         32.0   -99999.0   Rain         NaN
# 5   01-06-2017         31.0        2.0  Sunny         NaN
# 6   01-06-2017         34.0        5.0      0         NaN
# 7          NaN          NaN        NaN    NaN         NaN
# 8          NaN          NaN        NaN    NaN         NaN
# 9          NaN          NaN        NaN    NaN         NaN
# 10         NaN          NaN        NaN    NaN         NaN
# 11         NaN          NaN        NaN    NaN         NaN
# 12         NaN          NaN        NaN    NaN         NaN
# 13         NaN          NaN        NaN    NaN         NaN
# 14         NaN          NaN        NaN    NaN         NaN
# ...

# %%
new_df = df.replace({
    'NaN':'Sunny'
})
new_df
# Out:
#            day  temperature  windspeed  event  Unnamed: 4
# 0   01-01-2017         32.0        6.0   Rain         NaN
# 1   01-02-2017     -99999.0        7.0  Sunny         NaN
# 2   01-03-2017         28.0   -99999.0   Snow         NaN
# 3   01-04-2017     -99999.0        7.0      0         NaN
# 4   01-05-2017         32.0   -99999.0   Rain         NaN
# 5   01-06-2017         31.0        2.0  Sunny         NaN
# 6   01-06-2017         34.0        5.0      0         NaN
# 7          NaN          NaN        NaN    NaN         NaN
# 8          NaN          NaN        NaN    NaN         NaN
# 9          NaN          NaN        NaN    NaN         NaN
# 10         NaN          NaN        NaN    NaN         NaN
# 11         NaN          NaN        NaN    NaN         NaN
# 12         NaN          NaN        NaN    NaN         NaN
# 13         NaN          NaN        NaN    NaN         NaN
# 14         NaN          NaN        NaN    NaN         NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Hp\\OneDrive\\Documents\\weather_by_cities.csv")
df
# Out:
#            day      city  temperature  windspeed   event  Unnamed: 5
# 0   01-01-2017  new york           32          6    Rain         NaN
# 1   01-02-2017  new york           36          7   Sunny         NaN
# 2   01-03-2017  new york           28         12    Snow         NaN
# 3   01-04-2017  new york           33          7   Sunny         NaN
# 4   01-01-2017    mumbai           90          5   Sunny         NaN
# 5   01-02-2017    mumbai           85         12     Fog         NaN
# 6   01-03-2017    mumbai           87         15     Fog         NaN
# 7   01-04-2017    mumbai           92          5    Rain         NaN
# 8   01-01-2017     paris           45         20   Sunny         NaN
# 9   01-02-2017     paris           50         13  Cloudy         NaN
# 10  01-03-2017     paris           54          8  Cloudy         NaN
# 11  01-04-2017     paris           42         10  Cloudy         NaN

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event  Unnamed: 5
# 4  01-01-2017  mumbai           90          5  Sunny         NaN
# 5  01-02-2017  mumbai           85         12    Fog         NaN
# 6  01-03-2017  mumbai           87         15    Fog         NaN
# 7  01-04-2017  mumbai           92          5   Rain         NaN
# new york
#           day      city  temperature  windspeed  event  Unnamed: 5
# 0  01-01-2017  new york           32          6   Rain         NaN
# 1  01-02-2017  new york           36          7  Sunny         NaN
# 2  01-03-2017  new york           28         12   Snow         NaN
# 3  01-04-2017  new york           33          7  Sunny         NaN
# paris
#            day   city  temperature  windspeed   event  Unnamed: 5
# 8   01-01-2017  paris           45         20   Sunny         NaN
# 9   01-02-2017  paris           50         13  Cloudy         NaN
# 10  01-03-2017  paris           54          8  Cloudy         NaN
# ...

# %%
g = df.groupby('event')
g

# %%
for event, event_df in g:
    print(event)
    print(event_df)
# Out:
# Cloudy
#            day   city  temperature  windspeed   event  Unnamed: 5
# 9   01-02-2017  paris           50         13  Cloudy         NaN
# 10  01-03-2017  paris           54          8  Cloudy         NaN
# 11  01-04-2017  paris           42         10  Cloudy         NaN
# Fog
#           day    city  temperature  windspeed event  Unnamed: 5
# 5  01-02-2017  mumbai           85         12   Fog         NaN
# 6  01-03-2017  mumbai           87         15   Fog         NaN
# Rain
#           day      city  temperature  windspeed event  Unnamed: 5
# 0  01-01-2017  new york           32          6  Rain         NaN
# 7  01-04-2017    mumbai           92          5  Rain         NaN
# Snow
#           day      city  temperature  windspeed event  Unnamed: 5
# 2  01-03-2017  new york           28         12  Snow         NaN
# Sunny
#           day      city  temperature  windspeed  event  Unnamed: 5
# 1  01-02-2017  new york           36          7  Sunny         NaN
# ...

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event  Unnamed: 5
# 4  01-01-2017  mumbai           90          5  Sunny         NaN
# 5  01-02-2017  mumbai           85         12    Fog         NaN
# 6  01-03-2017  mumbai           87         15    Fog         NaN
# 7  01-04-2017  mumbai           92          5   Rain         NaN
# new york
#           day      city  temperature  windspeed  event  Unnamed: 5
# 0  01-01-2017  new york           32          6   Rain         NaN
# 1  01-02-2017  new york           36          7  Sunny         NaN
# 2  01-03-2017  new york           28         12   Snow         NaN
# 3  01-04-2017  new york           33          7  Sunny         NaN
# paris
#            day   city  temperature  windspeed   event  Unnamed: 5
# 8   01-01-2017  paris           45         20   Sunny         NaN
# 9   01-02-2017  paris           50         13  Cloudy         NaN
# 10  01-03-2017  paris           54          8  Cloudy         NaN
# ...

# %%
g.get_group('mumbai')
# Out:
#           day    city  temperature  windspeed  event  Unnamed: 5
# 4  01-01-2017  mumbai           90          5  Sunny         NaN
# 5  01-02-2017  mumbai           85         12    Fog         NaN
# 6  01-03-2017  mumbai           87         15    Fog         NaN
# 7  01-04-2017  mumbai           92          5   Rain         NaN

# %%
g.max()
# Out:
#                  day  temperature  windspeed  event  Unnamed: 5
# city
# mumbai    01-04-2017           92         15  Sunny         NaN
# new york  01-04-2017           36         12  Sunny         NaN
# paris     01-04-2017           54         20  Sunny         NaN

# %%
g.mean()
# Out:
#           temperature  windspeed  Unnamed: 5
# city
# mumbai          88.50       9.25         NaN
# new york        32.25       8.00         NaN
# paris           47.75      12.75         NaN

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed         ...              Unnamed: 5                       \
#              count   mean  ...    75%   max      count mean std min 25% 50%
# city                       ...
# mumbai         4.0   9.25  ...  12.75  15.0        0.0  NaN NaN NaN NaN NaN
# new york       4.0   8.00  ...   8.25  12.0        0.0  NaN NaN NaN NaN NaN
# paris          4.0  12.75  ...  14.75  20.0        0.0  NaN NaN NaN NaN NaN
#
#
#          75% max
# city
# mumbai   NaN NaN
# new york NaN NaN
# paris    NaN NaN
#
# [3 rows x 24 columns]

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.11;0.775x0.77)
# new york    AxesSubplot(0.125,0.11;0.775x0.77)
# paris       AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
import pandas as pd

india_weather = pd.DataFrame({
        "city":["mumbai", "delhi", "pune"],
        "temperature":[40, 25, 32],
        "humidity":[70, 20, 39]
})
india_weather
# Out:
#      city  temperature  humidity
# 0  mumbai           40        70
# 1   delhi           25        20
# 2    pune           32        39

# %%
us_weather = pd.DataFrame({
        "city":["washington", "chicago", "newyork"],
        "temperature":[20, 15, 18],
        "humidity":[12,23,13]
})
us_weather
# Out:
#          city  temperature  humidity
# 0  washington           20        12
# 1     chicago           15        23
# 2     newyork           18        13

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#          city  temperature  humidity
# 0      mumbai           40        70
# 1       delhi           25        20
# 2        pune           32        39
# 0  washington           20        12
# 1     chicago           15        23
# 2     newyork           18        13

# %%
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#          city  temperature  humidity
# 0      mumbai           40        70
# 1       delhi           25        20
# 2        pune           32        39
# 3  washington           20        12
# 4     chicago           15        23
# 5     newyork           18        13

# %%
df = pd.concat([india_weather, us_weather], keys = ["india", "us"])
df
# Out:
#                city  temperature  humidity
# india 0      mumbai           40        70
#       1       delhi           25        20
#       2        pune           32        39
# us    0  washington           20        12
#       1     chicago           15        23
#       2     newyork           18        13

# %%
df.loc["india"]
# Out:
#      city  temperature  humidity
# 0  mumbai           40        70
# 1   delhi           25        20
# 2    pune           32        39

# %%
import pandas as pd
temperature_df = pd.DataFrame({
    "city":["mumbai", "delhi", "kolkata"],
    "temperature":[30, 40, 35]
})
temperature_df
# Out:
#       city  temperature
# 0   mumbai           30
# 1    delhi           40
# 2  kolkata           35

# %%
import pandas as pd
windspeed_df = pd.DataFrame({
    "city":["mumbai", "delhi", "kolkata"],
    "windspeed":[20, 50, 25]
})
windspeed_df
# Out:
#       city  windspeed
# 0   mumbai         20
# 1    delhi         50
# 2  kolkata         25

# %%
df = pd.concat([temperature_df, windspeed_df])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7560\3854902257.py in <module>
# ----> 1 df = pd.concat([temperature_df, windspeed_df])
#       2 df
#
# NameError: name 'temperature_df' is not defined

# %%
df = pd.concat([temperature_df, windspeed_df], ignore_index = True)
df
# Out:
#       city  temperature
# 0   mumbai           30
# 1    delhi           40
# 2  kolkata           35
# 3   mumbai           20
# 4    delhi           50
# 5  kolkata           25

# %%
df = pd.concat([temperature_df, windspeed_df], axis = 1)
df
# Out:
#       city  temperature     city  temperature
# 0   mumbai           30   mumbai           20
# 1    delhi           40    delhi           50
# 2  kolkata           35  kolkata           25
