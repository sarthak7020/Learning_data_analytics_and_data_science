# %%
# correlation coefficient

import math
import matplotlib.pyplot as plt

# function for correlation coefficient.
def correlationCoefficient(X, Y, n) :
    sum_X = 0
    sum_Y = 0
    sum_XY = 0
    squareSum_X = 0
    squareSum_Y = 0
     
    i = 0
    while i < n :  #n-> length of arr
        
# sum of all x values
        sum_X = sum_X + X[i]
         
# sum of all y values
        sum_Y = sum_Y + Y[i]
         
# sum of X[i] * Y[i].
        
        sum_XY = sum_XY + X[i] * Y[i]
         
# sum of square of array elements.
        squareSum_X = squareSum_X + X[i] * X[i]
        squareSum_Y = squareSum_Y + Y[i] * Y[i]
         
        i = i + 1
        
#formula for correlation coefficient.
    corr = (float)(n * sum_XY - sum_X * sum_Y)/(float)(math.sqrt((n * squareSum_X -sum_X * sum_X)* (n * squareSum_Y -sum_Y * sum_Y)))
    return corr
     

X = [34,32,30,29,27]
Y = [2,4,6,8,12]
      
n = len(X)

corr_coeff=correlationCoefficient(X, Y, n)
print("Correlation coefficient:", corr_coeff)
plt.plot(X,Y)
# Out:
# Correlation coefficient: -0.9813137496771572
